# %% [markdown]
# # Lesson 1 - ECG Classifier

# %% [markdown]
# Project 2: Classify between ECG arrythmias: F, Q, V, S and N hearbeat types.
#
# Data is obtained from the MITBIH Arrhythmia dataset:
# https://www.physionet.org/physiobank/database/mitdb/

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 32
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %%
path = Path('/fastai/data/ECG_data')

# %%
path.ls()
# Out:
# [PosixPath('/fastai/data/ECG_data/mitbih_to_2D.py'),
#  PosixPath('/fastai/data/ECG_data/README.md'),
#  PosixPath('/fastai/data/ECG_data/train.py'),
#  PosixPath('/fastai/data/ECG_data/preprocess2.py'),
#  PosixPath('/fastai/data/ECG_data/models'),
#  PosixPath('/fastai/data/ECG_data/train2.py'),
#  PosixPath('/fastai/data/ECG_data/preprocess_2D.py'),
#  PosixPath('/fastai/data/ECG_data/check_result.py'),
#  PosixPath('/fastai/data/ECG_data/train_2D.py'),
#  PosixPath('/fastai/data/ECG_data/print_models.py'),
#  PosixPath('/fastai/data/ECG_data/ECG_Class.ipynb'),
#  PosixPath('/fastai/data/ECG_data/train'),
#  PosixPath('/fastai/data/ECG_data/preprocess.py'),
#  PosixPath('/fastai/data/ECG_data/mitbih'),
#  PosixPath('/fastai/data/ECG_data/valid')]

# %%
classes = ['N','Q', 'F', 'S', 'V']

# %% [markdown]
# Data is organized into a dataset following the instructions on https://github.com/fastai/course-v3/blob/master/nbs/dl1/lesson2-download.ipynb

# %%
for c in classes:
    print(c)
    verify_images(path/'train'/c, delete=True, max_size=500)
# Out:
# N
# Image /fastai/data/ECG_data/train/N/N7508.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N27448.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N35606.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N47.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26187.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N21885.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N30678.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29474.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N37506.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N3938.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N18191.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N23657.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N329.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N33338.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N9126.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N8339.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N37335.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N22213.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N33091.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N3592.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N4030.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29902.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N32025.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N32608.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29050.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29946.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N1368.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N10308.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N2208.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N13699.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N16730.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N18238.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N27009.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N12831.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N16536.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N3363.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N7967.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26751.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N37573.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N18886.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26353.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N9977.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N14481.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26776.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28748.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N30989.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N30164.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26017.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N11757.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N4901.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N17449.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N1208.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28683.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N13767.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N1904.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N31874.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N21594.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N32474.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N30300.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29801.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N7464.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29708.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N4321.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N23071.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38418.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N23453.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29901.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N12316.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N3453.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N1161.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N12070.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N12368.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N8106.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38031.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N25909.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19921.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N23555.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19861.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N5604.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N32221.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N2760.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28642.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38221.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N35422.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19329.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N18786.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19834.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N35777.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N35559.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N4275.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N8764.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38813.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N9698.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28708.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N10108.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N8095.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N5551.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N25283.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28315.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38596.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N
png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29355.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N5362.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N14447.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N5818.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N9339.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N32086.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N14769.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N23262.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N37424.png has 4 instead of 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/fastai/vision/data.py in verify_images(path, delete, max_workers, max_size, dest, n_channels, interp, ext, img_format, resume, **kwargs)
#     277                              interp=interp, ext=ext, img_format=img_format, resume=resume, **kwargs) for f in files]
# --> 278         for f in progress_bar(as_completed(futures), total=len(files)): pass
#     279
#
# /opt/conda/lib/python3.6/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      64         try:
# ---> 65             for i,o in enumerate(self._gen):
#      66                 yield o
#
# /opt/conda/lib/python3.6/concurrent/futures/_base.py in as_completed(fs, timeout)
#     239
# --> 240             waiter.event.wait(wait_timeout)
#     241
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-fda5419d2eb5> in <module>()
#       1 for c in classes:
#       2     print(c)
# ----> 3     verify_images(path/'train'/c, delete=True, max_size=500)
#
# /opt/conda/lib/python3.6/site-packages/fastai/vision/data.py in verify_images(path, delete, max_workers, max_size, dest, n_channels, interp, ext, img_format, resume, **kwargs)
#     276         futures = [ex.submit(verify_image, f, delete=delete, max_size=max_size, dest=dest, n_channels=n_channels,
#     277                              interp=interp, ext=ext, img_format=img_format, resume=resume, **kwargs) for f in files]
# --> 278         for f in progress_bar(as_completed(futures), total=len(files)): pass
#     279
#     280 class ImageItemList(ItemList):
#
# /opt/conda/lib/python3.6/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     609
#     610     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 611         self.shutdown(wait=True)
#     612         return False
#
# /opt/conda/lib/python3.6/concurrent/futures/process.py in shutdown(self, wait)
#     504             self._result_queue.put(None)
#     505             if wait:
# --> 506                 self._queue_management_thread.join()
#     507         # To reduce the risk of opening too many files, remove references to
#     508         # objects that use file descriptors.
#
# /opt/conda/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# /opt/conda/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:
# Image /fastai/data/ECG_data/train/N/N14688.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N24522.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N14527.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N10228.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N35354.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N33436.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N15380.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N21338.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N2855.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N12666.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N27689.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N1404.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N24752.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N7041.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29858.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N16711.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N33435.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N6590.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N6462.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N36656.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N23700.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19675.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28292.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N17294.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N15274.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N4221.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N6756.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N32750.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N20325.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N36772.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N34379.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N17539.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19182.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N27160.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N17982.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N33672.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N15573.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N7993.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N36003.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N29018.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N1750.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26458.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N16772.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26262.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N7803.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N37091.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N8022.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N16728.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N6691.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N24937.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N22268.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N22836.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N5295.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N2660.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N15085.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N25911.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N17042.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38975.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N16436.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N18325.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N2109.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N3312.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N7465.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N7643.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N13068.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N25262.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N25954.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28312.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38534.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N18941.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N15610.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N15216.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N10277.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N18619.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19843.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N38193.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26887.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N17583.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N8542.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N26665.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N19618.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N3575.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N9130.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N20895.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N3403.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N2850.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N37167.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N21659.png has 4 instead of 3
# Image /fastai/data/ECG_data/train/N/N28830.png has 4 instead of 3

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['sketch', 'painting', 'picture']
# (3, 3)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories.
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:03<00:00, 22135996.85it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:28
# epoch  train_loss  valid_loss  error_rate
# 1      0.818929    0.308297    0.098976    (00:07)
# 2      0.490937    0.191932    0.068259    (00:07)
# 3      0.338398    0.185909    0.068259    (00:06)
# 4      0.254723    0.177340    0.051195    (00:06)

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %% [markdown]
# As we can see, most of the confussions happen because of incorrectly labelled data (labeled as sketch when its a painting/picture, or two-way viceversa), or when one of the images looks a lot like of other category, like a very realistic painting categorized as pictre.

# %%
doc(interp.plot_top_losses)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('painting', 'picture', 6),
#  ('sketch', 'painting', 4),
#  ('picture', 'painting', 3)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 00:15
# epoch  train_loss  valid_loss  error_rate
# 1      0.149367    0.168732    0.051195    (00:08)
# 2      0.141142    0.168372    0.061433    (00:06)

# %%
learn.save('stage-1')

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
# data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=299, bs=bs//2).normalize(imagenet_stats)
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, bs=bs//2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-03/2
learn.fit_one_cycle(6, slice(lr))
# Out:
# Total time: 00:44
# epoch  train_loss  valid_loss  error_rate
# 1      0.159540    0.159934    0.061433    (00:07)
# 2      0.148692    0.180633    0.058020    (00:07)
# 3      0.127864    0.177995    0.064846    (00:07)
# 4      0.140372    0.146324    0.054607    (00:07)
# 5      0.114216    0.165258    0.058020    (00:07)
# 6      0.105334    0.170623    0.061433    (00:07)

# %%
learn.recorder.plot()

# %%
learn.save('stage-1-50')

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,2e-4))
# Out:
# Total time: 00:28
# epoch  train_loss  valid_loss  error_rate
# 1      0.118233    0.153404    0.054607    (00:09)
# 2      0.129882    0.171021    0.061433    (00:09)
# 3      0.101149    0.154631    0.051195    (00:08)

# %% [markdown]
# If it doesn't, you can always go back to your previous model.

# %%
learn.save('stage-2-50');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
# Out:
# [('sketch', 'painting', 5),
#  ('painting', 'picture', 5),
#  ('picture', 'painting', 4)]

# %% [markdown]
# # Predict class:

# %% [markdown]
# Create a netowrk for inference and load the latest trained model:

# %%
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)

# %%
learn = create_cnn(data2, models.resnet50).load('stage-2-50')

# %% [markdown]
# Select a class at random and a picture of that class at random:

# %%
test_class = classes[random.randint(0, data.c-1)]
test_names = get_image_files(path/test_class)
test_class
# Out:
# 'sketch'

# %%
n_img = len(test_names)
img_f = test_names[random.randint(0, n_img-1)]
img = open_image(img_f)
img
# Out:
# Image (3, 500, 403)

# %% [markdown]
# Classify the image:

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'sketch'

# %% [markdown]
# Or all at once:

# %%
test_class = classes[random.randint(0, data.c-1)]
test_names = get_image_files(path/test_class)
n_img = len(test_names)
img_f = test_names[random.randint(0, n_img-1)]
img = open_image(img_f)
pred_class,pred_idx,outputs = learn.predict(img)
img
# Out:
# Image (3, 333, 499)

# %%
pred_class
# Out:
# 'sketch'
